# %%
# !pip install xlrd

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Reynolds

# %% [markdown]
# ## load daily soil temperature

# %%
import os
fdir = "data/Reynolds/soiltemperature"

def loadReynolds(fname):
    df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)
    df = df[df[3]==17]
    df_time = pd.to_datetime(df[0].astype(str) +  ' ' + df[1].astype(str) + ' ' + df[2].astype(str),format="%m %d %Y")
    
    df2 = df[[5,6,7,8,9,10,11,12]].replace('.', np.nan).astype(float).ffill(axis=0)

    df2[1] = fname.replace(fdir,"").replace("/hourly","").replace("soiltemperature.txt","")
    
    return pd.concat([df_time,df2], axis=1) 

soil_temp = []
for file in os.listdir(fdir):
    if file.endswith(".txt") and file.find("hourly") > -1:
        print(file)
        path = os.path.join(fdir, file)
        soil_temp += [loadReynolds(path)]

reynolds_soil_temp = pd.concat(soil_temp, axis=0)
# Out:
# hourly127x07soiltemperature.txt
# hourly098x97soiltemperature.txt
# /tmp/ipykernel_69623/1031154991.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)
# /tmp/ipykernel_69623/1031154991.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)
# hourly076x59soiltemperature.txt
# hourly057x96soiltemperature.txt
# hourly176x14soiltemperature.txt
# /tmp/ipykernel_69623/1031154991.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)
# /tmp/ipykernel_69623/1031154991.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)
# /tmp/ipykernel_69623/1031154991.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)

# %%
fdir2 = "data/Reynolds"

def loadReynoldsCL(fname):
    df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)
    df = df[(df[2] > 1984)|(df[2] == 1984) & (df[0] == 12) &(df[1] > 4)]
    df_time = pd.to_datetime(df[0].astype(str) +  ' ' + df[1].astype(str) + ' ' + df[2].astype(str),format="%m %d %Y")
    
    df2 = df[[3,4]].replace('.', np.nan).astype(float).ffill(axis=0)

    df2[1] = fname.replace(fdir2,"").replace("/daily","").replace("climate.txt","")
    
    return pd.concat([df_time,df2], axis=1) 

climate = []
for file in os.listdir(fdir2):
    if file.endswith(".txt") and file.find("daily") > -1:
        print(file)
        path = os.path.join(fdir2, file)
        climate += [loadReynoldsCL(path)]

reynolds_climate = pd.concat(climate, axis=0)
# Out:
# daily176x14climate.txt
# daily127x07climate.txt
# daily076x59climate.txt
# /tmp/ipykernel_69623/649803734.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)
# /tmp/ipykernel_69623/649803734.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)
# /tmp/ipykernel_69623/649803734.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(fname, delim_whitespace=True,comment="#", encoding="ISO-8859-1",on_bad_lines="warn",header=None)

# %%
reynolds_soil_temp = reynolds_soil_temp.rename(columns={0:'DATE',1:"LOC",5:"y_1",6:"y_2",7:"y_3",8:"y_4",9:"y_5",10:"y_6",11:"y_7",12:"y_8",3: 20, 4: 21}) 
reynolds_climate = reynolds_climate.rename(columns={0:'DATE',1:"LOC"})
climate = reynolds_climate.set_index(['DATE','LOC']).rename(columns={3: "C1", 4: "C2"}) 
soil = reynolds_soil_temp.set_index(['DATE','LOC'])

# %%
all_reynolds_data = pd.merge(soil,climate,left_index=True, right_index=True)

# %%
all_reynolds_data.to_csv("all_reynolds_data.csv",sep=";")

# %%
all_reynolds_data
# Out:
#                     y_1   y_2   y_3   y_4   y_5   y_6   y_7   y_8    C1    C2
# DATE       LOC
# 1984-12-05 127x07   NaN   0.4   NaN   2.0   NaN   NaN   NaN   NaN  -9.8  -2.4
# 1984-12-06 127x07   NaN   0.3   NaN   1.9   NaN   NaN   NaN   NaN  -9.4  -1.0
# 1984-12-07 127x07   NaN   0.2   NaN   1.8   NaN   NaN   NaN   NaN  -5.2   3.6
# 1984-12-08 127x07   NaN   0.1   NaN   1.7   NaN   NaN   NaN   NaN  -3.6   4.0
# 1984-12-09 127x07   NaN   0.2   NaN   1.6   NaN   NaN   NaN   NaN  -0.1   5.1
# ...                 ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1996-09-26 176x14  15.4  12.5   9.5   9.6  10.2  10.4  10.8  11.0  -1.1   9.6
# 1996-09-27 176x14  18.4  14.8  10.3  10.2  10.2  10.4  10.7  10.9   1.9  17.0
# 1996-09-28 176x14  19.9  16.6  12.0  11.7  11.0  11.0  10.9  10.9  10.1  21.2
# 1996-09-29 176x14  20.5  17.6  13.1  12.8  11.9  11.7  11.4  11.0  12.4  21.9
# 1996-09-30 176x14  20.4  17.6  13.5  13.2  12.4  12.2  11.9  11.2  13.2  21.8
#
# [9969 rows x 10 columns]

# %% [markdown]
# # UK

# %%
uk_data = "data/UK/catalogue.ceh.ac.uk/datastore/eidchub/1/"
climate_soil = []

def loadUK(fname):
    df = pd.read_csv(fname, sep=",",comment="#", on_bad_lines="warn")

    df1 = df.iloc[:, :2]
    df2 = df.iloc[:, 2:]    
    df2 = df2.astype(float).replace(-9999.0, np.nan).ffill(axis=0)    
    
    return pd.concat([df1,df2], axis=1)
    

for file in os.listdir(uk_data):
    if file.endswith(".csv") and file.find("daily") > -1 and file.find("flags") == -1 and file.find("metadata") == -1:
        print(file)
        path = os.path.join(uk_data, file)
        climate_soil += [loadUK(path)]

climate_soil =  pd.concat(climate_soil, axis=0)
climate_soil = climate_soil.rename(columns={"DATE_TIME":"DATE","SITE_ID":"LOC","TDT1_TSOIL":"y_1","TDT2_TSOIL":"y_2","TDT3_TSOIL":"y_3","TDT4_TSOIL":"y_4","TDT5_TSOIL":"y_5","TDT6_TSOIL":"y_6","TDT7_TSOIL":"y_7","TDT8_TSOIL":"y_8","TDT9_TSOIL":"y_9","TDT10_TSOIL":"y_10"}) 
climate_soil['DATE']= pd.to_datetime(climate_soil['DATE'])
climate_soil.set_index(["DATE","LOC"])
# Out:
# cosmos-uk_alic1_hydrosoil_daily_2015-2022.csv
# cosmos-uk_tadhm_hydrosoil_daily_2014-2022.csv
# cosmos-uk_crich_hydrosoil_daily_2014-2022.csv
# cosmos-uk_lizrd_hydrosoil_daily_2014-2022.csv
# cosmos-uk_morly_hydrosoil_daily_2014-2022.csv
# cosmos-uk_redhl_hydrosoil_daily_2016-2022.csv
# cosmos-uk_sourh_hydrosoil_daily_2014-2022.csv
# cosmos-uk_plynl_hydrosoil_daily_2014-2022.csv
# cosmos-uk_wrttl_hydrosoil_daily_2017-2022.csv
# cosmos-uk_sydlg_hydrosoil_daily_2018-2022.csv
# cosmos-uk_glens_hydrosoil_daily_2014-2022.csv
# cosmos-uk_holln_hydrosoil_daily_2014-2022.csv
# cosmos-uk_hartw_hydrosoil_daily_2014-2022.csv
# cosmos-uk_hillb_hydrosoil_daily_2016-2022.csv
# cosmos-uk_bickl_hydrosoil_daily_2015-2022.csv
# cosmos-uk_cardt_hydrosoil_daily_2015-2022.csv
# cosmos-uk_moorh_hydrosoil_daily_2014-2022.csv
# cosmos-uk_eustn_hydrosoil_daily_2016-2022.csv
# cosmos-uk_eastb_hydrosoil_daily_2014-2022.csv
# cosmos-uk_riseh_hydrosoil_daily_2016-2022.csv
# cosmos-uk_hybry_hydrosoil_daily_2017-2022.csv
# cosmos-uk_rothd_hydrosoil_daily_2014-2022.csv
# cosmos-uk_balrd_hydrosoil_daily_2014-2022.csv
# cosmos-uk_wyth1_hydrosoil_daily_2013-2022.csv
# cosmos-uk_nwyke_hydrosoil_daily_2014-2022.csv
# cosmos-uk_fivet_hydrosoil_daily_2018-2022.csv
# cosmos-uk_chobh_hydrosoil_daily_2015-2022.csv
# cosmos-uk_glenw_hydrosoil_daily_2016-2022.csv
# cosmos-uk_stght_hydrosoil_daily_2015-2022.csv
# cosmos-uk_lulln_hydrosoil_daily_2014-2022.csv
# cosmos-uk_hadlw_hydrosoil_daily_2016-2022.csv
# cosmos-uk_harwd_hydrosoil_daily_2015-2022.csv
# cosmos-uk_henfs_hydrosoil_daily_2015-2022.csv
# cosmos-uk_hlacy_hydrosoil_daily_2018-2022.csv
# cosmos-uk_cgarw_hydrosoil_daily_2016-2022.csv
# cosmos-uk_sheep_hydrosoil_daily_2013-2022.csv
# cosmos-uk_finch_hydrosoil_daily_2017-2022.csv
# cosmos-uk_gisbn_hydrosoil_daily_2014-2022.csv
# cosmos-uk_bunny_hydrosoil_daily_2015-2022.csv
# cosmos-uk_elmst_hydrosoil_daily_2016-2022.csv
# cosmos-uk_lodtn_hydrosoil_daily_2016-2022.csv
# cosmos-uk_waddn_hydrosoil_daily_2013-2022.csv
# cosmos-uk_chimn_hydrosoil_daily_2013-2022.csv
# cosmos-uk_wimpl_hydrosoil_daily_2019-2022.csv
# cosmos-uk_portn_hydrosoil_daily_2014-2022.csv
# cosmos-uk_spenf_hydrosoil_daily_2016-2022.csv
# cosmos-uk_morem_hydrosoil_daily_2018-2022.csv
# cosmos-uk_cochn_hydrosoil_daily_2017-2022.csv
# cosmos-uk_rdmer_hydrosoil_daily_2015-2022.csv
# cosmos-uk_coclp_hydrosoil_daily_2014-2022.csv
# cosmos-uk_stips_hydrosoil_daily_2014-2022.csv
#                   LWIN  LWOUT  SWIN  SWOUT   RN  PRECIP  PRECIP_TIPPING  \
# DATE       LOC
# 2015-03-06 ALIC1   NaN    NaN   NaN    NaN  NaN     NaN             NaN
# 2015-03-07 ALIC1  23.7   30.5  13.3    1.9  4.6     0.0             NaN
# 2015-03-08 ALIC1  27.1   30.5   4.8    0.7  0.7     0.0             NaN
# 2015-03-09 ALIC1  28.3   29.7   2.4    0.4  0.7     0.1             NaN
# 2015-03-10 ALIC1  23.5   29.8  12.4    1.8  4.3     0.0             NaN
# ...                ...    ...   ...    ...  ...     ...             ...
# 2022-12-27 STIPS  28.4   29.0   0.4    0.1 -0.3     2.9             NaN
# 2022-12-28 STIPS  29.1   29.8   0.6    0.1 -0.2     6.4             NaN
# 2022-12-29 STIPS  26.3   28.7   1.7    0.4 -1.1     2.5             NaN
# 2022-12-30 STIPS  27.1   29.6   1.2    0.2 -1.5     2.0             NaN
# 2022-12-31 STIPS  30.1   30.4   0.7    0.1  0.3    21.6             NaN
#
#                   PRECIP_RAINE      PA   TA  ...  STP_TSOIL50  COSMOS_VWC  \
# DATE       LOC                               ...
# 2015-03-06 ALIC1           NaN     NaN  NaN  ...          NaN         NaN
# 2015-03-07 ALIC1           NaN  1012.2  8.6  ...          5.6        40.8
# 2015-03-08 ALIC1           NaN  1010.3  8.4  ...          5.7        42.9
# 2015-03-09 ALIC1           NaN  1011.8  6.2  ...          5.9        38.8
# 2015-03-10 ALIC1           NaN  1016.6  7.2  ...          5.9        45.9
# ...                        ...     ...  ...  ...          ...         ...
# 2022-12-27 STIPS           NaN   962.5  4.7  ...          6.3        52.5
# 2022-12-28 STIPS           NaN   945.7  6.4  ...          6.2        52.5
# 2022-12-29 STIPS           NaN   946.7  4.1  ...          6.3        52.5
# 2022-12-30 STIPS           NaN   941.3  6.2  ...          6.3        52.5
# 2022-12-31 STIPS           NaN   945.3  7.6  ...          6.4        52.5
#
#                   CTS_MOD_CORR   D86_75M  SNOW  SNOW_DEPTH      SWE  ALBEDO  \
# DATE       LOC
# 2015-03-06 ALIC1           NaN       NaN   NaN         NaN      NaN     NaN
# 2015-03-07 ALIC1    1129.96052  22.50153   0.0         NaN      NaN   0.126
# 2015-03-08 ALIC1    1120.16381  22.02295   0.0         NaN      NaN   0.116
# 2015-03-09 ALIC1    1140.46891  22.99462   0.0         NaN      NaN   0.111
# 2015-03-10 ALIC1    1106.90799  21.40022   0.0         NaN      NaN   0.121
# ...                        ...       ...   ...         ...      ...     ...
# 2022-12-27 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.139
# 2022-12-28 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.138
# 2022-12-29 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.189
# 2022-12-30 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.152
# 2022-12-31 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.161
#
#                    PE    GCC
# DATE       LOC
# 2015-03-06 ALIC1  NaN    NaN
# 2015-03-07 ALIC1  1.5    NaN
# 2015-03-08 ALIC1  0.4    NaN
# 2015-03-09 ALIC1  0.2    NaN
# 2015-03-10 ALIC1  1.4    NaN
# ...               ...    ...
# 2022-12-27 STIPS  0.1  0.335
# 2022-12-28 STIPS  0.3  0.334
# 2022-12-29 STIPS  0.4  0.334
# 2022-12-30 STIPS  0.4  0.334
# 2022-12-31 STIPS  0.2  0.336
#
# [135654 rows x 50 columns]

# %%
climate_soil.rename(columns={"DATE_TIME":"DATE","SITE_ID":"LOC","TDT1_TSOIL":"y_1","TDT2_TSOIL":"y_2","TDT3_TSOIL":"y_3","TDT4_TSOIL":"y_4","TDT5_TSOIL":"y_5","TDT6_TSOIL":"y_6","TDT7_TSOIL":"y_7","TDT8_TSOIL":"y_8","TDT9_TSOIL":"y_9","TDT10_TSOIL":"y_10"}) 
climate_soil = climate_soil.set_index(["DATE","LOC"])

# %%
climate_soil.to_csv("uk_soil.csv",sep=";")

# %%
climate_soil
# Out:
#                   LWIN  LWOUT  SWIN  SWOUT   RN  PRECIP  PRECIP_TIPPING  \
# DATE       LOC
# 2015-03-06 ALIC1   NaN    NaN   NaN    NaN  NaN     NaN             NaN
# 2015-03-07 ALIC1  23.7   30.5  13.3    1.9  4.6     0.0             NaN
# 2015-03-08 ALIC1  27.1   30.5   4.8    0.7  0.7     0.0             NaN
# 2015-03-09 ALIC1  28.3   29.7   2.4    0.4  0.7     0.1             NaN
# 2015-03-10 ALIC1  23.5   29.8  12.4    1.8  4.3     0.0             NaN
# ...                ...    ...   ...    ...  ...     ...             ...
# 2022-12-27 STIPS  28.4   29.0   0.4    0.1 -0.3     2.9             NaN
# 2022-12-28 STIPS  29.1   29.8   0.6    0.1 -0.2     6.4             NaN
# 2022-12-29 STIPS  26.3   28.7   1.7    0.4 -1.1     2.5             NaN
# 2022-12-30 STIPS  27.1   29.6   1.2    0.2 -1.5     2.0             NaN
# 2022-12-31 STIPS  30.1   30.4   0.7    0.1  0.3    21.6             NaN
#
#                   PRECIP_RAINE      PA   TA  ...  STP_TSOIL50  COSMOS_VWC  \
# DATE       LOC                               ...
# 2015-03-06 ALIC1           NaN     NaN  NaN  ...          NaN         NaN
# 2015-03-07 ALIC1           NaN  1012.2  8.6  ...          5.6        40.8
# 2015-03-08 ALIC1           NaN  1010.3  8.4  ...          5.7        42.9
# 2015-03-09 ALIC1           NaN  1011.8  6.2  ...          5.9        38.8
# 2015-03-10 ALIC1           NaN  1016.6  7.2  ...          5.9        45.9
# ...                        ...     ...  ...  ...          ...         ...
# 2022-12-27 STIPS           NaN   962.5  4.7  ...          6.3        52.5
# 2022-12-28 STIPS           NaN   945.7  6.4  ...          6.2        52.5
# 2022-12-29 STIPS           NaN   946.7  4.1  ...          6.3        52.5
# 2022-12-30 STIPS           NaN   941.3  6.2  ...          6.3        52.5
# 2022-12-31 STIPS           NaN   945.3  7.6  ...          6.4        52.5
#
#                   CTS_MOD_CORR   D86_75M  SNOW  SNOW_DEPTH      SWE  ALBEDO  \
# DATE       LOC
# 2015-03-06 ALIC1           NaN       NaN   NaN         NaN      NaN     NaN
# 2015-03-07 ALIC1    1129.96052  22.50153   0.0         NaN      NaN   0.126
# 2015-03-08 ALIC1    1120.16381  22.02295   0.0         NaN      NaN   0.116
# 2015-03-09 ALIC1    1140.46891  22.99462   0.0         NaN      NaN   0.111
# 2015-03-10 ALIC1    1106.90799  21.40022   0.0         NaN      NaN   0.121
# ...                        ...       ...   ...         ...      ...     ...
# 2022-12-27 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.139
# 2022-12-28 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.138
# 2022-12-29 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.189
# 2022-12-30 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.152
# 2022-12-31 STIPS    1317.61816  32.53471   0.0         NaN  5.56238   0.161
#
#                    PE    GCC
# DATE       LOC
# 2015-03-06 ALIC1  NaN    NaN
# 2015-03-07 ALIC1  1.5    NaN
# 2015-03-08 ALIC1  0.4    NaN
# 2015-03-09 ALIC1  0.2    NaN
# 2015-03-10 ALIC1  1.4    NaN
# ...               ...    ...
# 2022-12-27 STIPS  0.1  0.335
# 2022-12-28 STIPS  0.3  0.334
# 2022-12-29 STIPS  0.4  0.334
# 2022-12-30 STIPS  0.4  0.334
# 2022-12-31 STIPS  0.2  0.336
#
# [135654 rows x 50 columns]

# %%
climate_soil = climate_soil.drop(["SNOW_DEPTH", "TDT1_VWC","TDT2_VWC","TDT3_VWC","TDT4_VWC","TDT5_VWC","TDT6_VWC","TDT7_VWC","TDT8_VWC","TDT9_VWC","TDT10_VWC","PRECIP_TIPPING","PRECIP_RAINE"],axis=1)

# %% [markdown]
# # Preprocessing of the Datasets

# %% [markdown]
# ### Split onto 28 day long fragments. Remove fragments, which do not containt more than 30% of target values.

# %% [markdown]
# ### We do not consider temperatures for other soil layers as fatures deliberatly.

# %%
from datetime import date, timedelta
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')

PERIOD = 28
TRHX = 0.3

def daterange(start_date, end_date, step):
    for n in range(0,int((end_date - start_date).days), step):
        yield start_date + timedelta(n)

all_data = []
for df in [all_reynolds_data, climate_soil]:
    locations = df.index.get_level_values(1)
    
    rdatasX = {}
    rdatasY = {}
    for l in set(locations):
        ld = df.query("LOC == '" + l + "'").reset_index().set_index("DATE").drop("LOC",axis=1)
        all_start = ld.index.min()
        all_end = ld.index.max()
    
        for start in daterange(all_start, all_end, PERIOD):
            end = start + timedelta(PERIOD)
            period_data = ld.loc[start:end]
            
            y_columns = set([c for c in df.columns if c.find("y_") > -1])
            not_y_columns = [c for c in df.columns if c.find("y_") == -1]
            for y_counter in y_columns:
                if y_counter not in rdatasX: 
                    rdatasX[y_counter] = []
                    rdatasY[y_counter] = []
                    
                y_ = period_data[y_counter].to_numpy().astype(float)
                y = y_[1:]
    
                nans = np.count_nonzero(np.isnan(y))
    
                if float(nans) / y.shape[0] < TRHX and y.shape[0] == PERIOD:
                    X = period_data[not_y_columns].to_numpy()[:-1].astype(float)
                    X = np.hstack([X,y_[:-1].reshape(-1,1)]) # add current y as a feature
                    old_dim = X.shape[1]
                    X = imp.fit_transform(X)
                    if X.shape[1] == old_dim:
                        nans = np.count_nonzero(np.isnan(X))
                        if nans == 0:
                            y = imp.fit_transform(y.reshape(-1,1)).reshape(y.shape)
                            rdatasX[y_counter].append(X)
                            rdatasY[y_counter].append(y)
                    
    all_data.append({k:[np.asarray(rdatasX[k]), np.asarray(rdatasY[k])] for k in rdatasX})
# Out:
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23 26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [26]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [ 5 23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [ 5 23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [23]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
all_data[0].keys()
# Out:
# dict_keys(['y_4', 'y_3', 'y_7', 'y_1', 'y_8', 'y_2', 'y_6', 'y_5'])

# %% [markdown]
# # Find hyperparameters

# %%
from sklearn.preprocessing import normalize

for k in all_data[0]:
    all_data[0][k][0] = normalize(all_data[0][k][0].reshape(-1,all_data[0][k][0].shape[2]),axis=0).reshape(all_data[0][k][0].shape)
    
for k in all_data[1]:
    all_data[1][k][0] = normalize(all_data[1][k][0].reshape(-1,all_data[1][k][0].shape[2]),axis=0).reshape(all_data[1][k][0].shape)

# %%
from sklearn.model_selection import train_test_split
dict_data = {}
dict_data["Reynolds"] = {}
dict_data["UK"] = {}

for k in all_data[0]:
    x01,x02,y01,y02 = train_test_split(all_data[0][k][0], all_data[0][k][1], test_size=0.3,random_state=42)
    dict_data["Reynolds"][k] = {"train":{"X":x01,"y":y01},"test":{"X":x02,"y":y02}}
    
for k in all_data[1]:
    x11,x12,y11,y12 = train_test_split(all_data[1][k][0], all_data[1][k][1],test_size=0.3,random_state=42)
    dict_data["UK"][k] = {"train":{"X":x11,"y":y11},"test":{"X":x12,"y":y12}} 

all_data = dict_data

# %% [markdown]
# ## XGBoost

# %%
# !pip install xgboost
# Out:
# DEPRECATION: Loading egg at /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/isanl_srl_framebank-0.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: xgboost in /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: numpy in /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from xgboost) (1.13.0)

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
xgb.set_config(verbosity=2)

model = xgb.XGBRegressor(max_depth=2)

for ds_name in all_data:
    for depth in all_data[ds_name]:
        dat = all_data[ds_name][depth]
        model.fit(dat["train"]["X"].reshape(-1,dat["train"]["X"].shape[2]), dat["train"]["y"].flatten())
        y_pred = model.predict(dat["test"]["X"].reshape(-1,dat["test"]["X"].shape[2]))
        mse_score = mean_squared_error(y_pred, dat["test"]["y"].flatten())
        mae_score = mean_absolute_error(y_pred, dat["test"]["y"].flatten())
        print(ds_name,depth,mse_score, mae_score, dat["test"]["y"].min(),dat["test"]["y"].max())

# %% [markdown]
# # LSTM

# %%
import tensorflow as tf

import optuna

epochs = 2000


def make_model(input_shape, hidden_size):
    input_layer = tf.keras.layers.Input(input_shape)
    #dim = tf.zeros([batch_size,hidden_size])  
    output_layer = tf.keras.layers.LSTM(4, return_sequences=True,dropout=0.1)(input_layer)#, initial_state=[dim, dim])
    output_layer2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1, activation='linear'))(output_layer)    
# 
    return tf.keras.models.Model(inputs=input_layer, outputs=output_layer2)
# 

#def objective(trial):

for ds_name in all_data:
    for depth in all_data[ds_name]:
        dat = all_data[ds_name][depth]
        x_train = dat["train"]["X"]
        x_test = dat["test"]["X"]
        Y_train = dat["train"]["y"]
        Y_test = dat["test"]["y"]
        batch_size = 4       
        model = make_model(input_shape=x_train.shape[1:],hidden_size=4)
        # 
        opt = tf.keras.optimizers.Adam(learning_rate=0.01)
        
        model.compile(
             optimizer=opt,
             loss="mean_squared_error",
             metrics=["mean_squared_error"],
        )
        
        history = model.fit(
             x_train,
             Y_train,
             batch_size=batch_size,
             epochs=epochs,
             verbose=0,
        )
        # 
        #batch_size = x_test.shape[0]
        y_pred = model.predict(x_test) #, batch_size=batch_size)
        mse_score = mean_squared_error(Y_test.flatten(),y_pred.flatten())
        mae_score = mean_absolute_error(Y_test.flatten(),y_pred.flatten())
        print(ds_name,depth,mse_score, mae_score, Y_test.min(),Y_test.max())     

        y_pred = model.predict(x_train) #, batch_size=batch_size)
        mse_score = mean_squared_error(Y_train.flatten(),y_pred.flatten())
        mae_score = mean_absolute_error(Y_train.flatten(),y_pred.flatten())
        print("train: ", ds_name,depth,mse_score, mae_score, Y_train.min(),Y_train.max())

# %%
# !pip install protobuf==4.21.12

# %%
import tensorflow as tf

import optuna

epochs = 2000


def make_model(input_shape, hidden_size):
    input_layer = tf.keras.layers.Input(input_shape)
    #dim = tf.zeros([batch_size,hidden_size])  
    output_layer = tf.keras.layers.LSTM(8, return_sequences=True,dropout=0.1)(input_layer)#, initial_state=[dim, dim])
    output_layer2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1, activation='linear'))(output_layer)    
# 
    return tf.keras.models.Model(inputs=input_layer, outputs=output_layer2)
# 

#def objective(trial):

for ds_name in all_data:
    for depth in all_data[ds_name]:
        dat = all_data[ds_name][depth]
        x_train = dat["train"]["X"]
        x_test = dat["test"]["X"]
        Y_train = dat["train"]["y"]
        Y_test = dat["test"]["y"]
        batch_size = 4       
        model = make_model(input_shape=x_train.shape[1:],hidden_size=4)
        # 
        opt = tf.keras.optimizers.Adam(learning_rate=0.01)
        
        model.compile(
             optimizer=opt,
             loss="mean_squared_error",
             metrics=["mean_squared_error"],
        )
        
        history = model.fit(
             x_train,
             Y_train,
             batch_size=batch_size,
             epochs=epochs,
             verbose=0,
        )
        # 
        #batch_size = x_test.shape[0]
        y_pred = model.predict(x_test) #, batch_size=batch_size)
        mse_score = mean_squared_error(Y_test.flatten(),y_pred.flatten())
        mae_score = mean_absolute_error(Y_test.flatten(),y_pred.flatten())
        print(ds_name,depth,mse_score, mae_score, Y_test.min(),Y_test.max())     

        y_pred = model.predict(x_train) #, batch_size=batch_size)
        mse_score = mean_squared_error(Y_train.flatten(),y_pred.flatten())
        mae_score = mean_absolute_error(Y_train.flatten(),y_pred.flatten())
        print("train: ", ds_name,depth,mse_score, mae_score, Y_train.min(),Y_train.max())

# %%
import tensorflow as tf

import optuna

epochs = 2000


def make_model(input_shape, hidden_size):
    input_layer = tf.keras.layers.Input(input_shape)
    #dim = tf.zeros([batch_size,hidden_size])  
    output_layer = tf.keras.layers.LSTM(2, return_sequences=True,dropout=0.1)(input_layer)#, initial_state=[dim, dim])
    output_layer2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1, activation='linear'))(output_layer)    
# 
    return tf.keras.models.Model(inputs=input_layer, outputs=output_layer2)
# 

#def objective(trial):

for ds_name in all_data:
    for depth in all_data[ds_name]:
        dat = all_data[ds_name][depth]
        x_train = dat["train"]["X"]
        x_test = dat["test"]["X"]
        Y_train = dat["train"]["y"]
        Y_test = dat["test"]["y"]
        batch_size = 4       
        model = make_model(input_shape=x_train.shape[1:],hidden_size=4)
        # 
        opt = tf.keras.optimizers.Adam(learning_rate=0.01)
        
        model.compile(
             optimizer=opt,
             loss="mean_squared_error",
             metrics=["mean_squared_error"],
        )
        
        history = model.fit(
             x_train,
             Y_train,
             batch_size=batch_size,
             epochs=epochs,
             verbose=0,
        )
        # 
        #batch_size = x_test.shape[0]
        y_pred = model.predict(x_test) #, batch_size=batch_size)
        mse_score = mean_squared_error(Y_test.flatten(),y_pred.flatten())
        mae_score = mean_absolute_error(Y_test.flatten(),y_pred.flatten())
        print(ds_name,depth,mse_score, mae_score, Y_test.min(),Y_test.max())     

        y_pred = model.predict(x_train) #, batch_size=batch_size)
        mse_score = mean_squared_error(Y_train.flatten(),y_pred.flatten())
        mae_score = mean_absolute_error(Y_train.flatten(),y_pred.flatten())
        print("train: ", ds_name,depth,mse_score, mae_score, Y_train.min(),Y_train.max())

# %% [markdown]
# # GRU

# %%
import tensorflow as tf
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

import optuna

epochs = 2000


def make_model(input_shape, hidden_size):
    input_layer = tf.keras.layers.Input(input_shape)
    #dim = tf.zeros([batch_size,hidden_size])  
    output_layer = tf.keras.layers.GRU(2, return_sequences=True,dropout=0.1)(input_layer)#, initial_state=[dim, dim])
    output_layer2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1, activation='linear'))(output_layer)    
# 
    return tf.keras.models.Model(inputs=input_layer, outputs=output_layer2)
# 

#def objective(trial):

for ds_name in all_data:
    for depth in all_data[ds_name]:
        dat = all_data[ds_name][depth]
        x_train = dat["train"]["X"]
        x_test = dat["test"]["X"]
        Y_train = dat["train"]["y"]
        Y_test = dat["test"]["y"]
        batch_size = 4       
        model = make_model(input_shape=x_train.shape[1:],hidden_size=4)
        # 
        opt = tf.keras.optimizers.Adam(learning_rate=0.01)
        
        model.compile(
             optimizer=opt,
             loss="mean_squared_error",
             metrics=["mean_squared_error"],
        )
        
        history = model.fit(
             x_train,
             Y_train,
             batch_size=batch_size,
             epochs=epochs,
             verbose=0,
        )
        # 
        #batch_size = x_test.shape[0]
        y_pred = model.predict(x_test) #, batch_size=batch_size)
        mse_score = mean_squared_error(Y_test.flatten(),y_pred.flatten())
        mae_score = mean_absolute_error(Y_test.flatten(),y_pred.flatten())
        print(ds_name,depth,mse_score, mae_score, Y_test.min(),Y_test.max())     

        y_pred = model.predict(x_train) #, batch_size=batch_size)
        mse_score = mean_squared_error(Y_train.flatten(),y_pred.flatten())
        mae_score = mean_absolute_error(Y_train.flatten(),y_pred.flatten())
        print("train: ", ds_name,depth,mse_score, mae_score, Y_train.min(),Y_train.max())

# %% [markdown]
# # Cascade Forest

# %%
from deepforest import CascadeForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


for ds_name in all_data:
    for depth in all_data[ds_name]:
        model = CascadeForestRegressor(random_state=1)
        dat = all_data[ds_name][depth]
        model.fit(dat["train"]["X"].reshape(-1,dat["train"]["X"].shape[2]), dat["train"]["y"].flatten())
        y_pred = model.predict(dat["test"]["X"].reshape(-1,dat["test"]["X"].shape[2]))
        mse_score = mean_squared_error(y_pred, dat["test"]["y"].flatten())
        mae_score = mean_absolute_error(y_pred, dat["test"]["y"].flatten())
        print(ds_name,depth,mse_score, mae_score, dat["test"]["y"].min(),dat["test"]["y"].max())
# Out:
# [2024-05-06 13:36:35.428] Start to fit the model:
# [2024-05-06 13:36:35.428] Fitting cascade layer = 0
# [2024-05-06 13:36:40.204] layer = 0  | Val MSE = 0.38234 | Elapsed = 4.775 s
# [2024-05-06 13:36:40.208] Fitting cascade layer = 1
# [2024-05-06 13:36:47.173] layer = 1  | Val MSE = 0.27379 | Elapsed = 6.965 s
# [2024-05-06 13:36:47.176] Fitting cascade layer = 2
# [2024-05-06 13:36:54.168] layer = 2  | Val MSE = 0.27769 | Elapsed = 6.991 s
# [2024-05-06 13:36:54.168] Early stopping counter: 1 out of 2
# [2024-05-06 13:36:54.171] Fitting cascade layer = 3
# [2024-05-06 13:37:01.222] layer = 3  | Val MSE = 0.27663 | Elapsed = 7.051 s
# [2024-05-06 13:37:01.222] Early stopping counter: 2 out of 2
# [2024-05-06 13:37:01.222] Handling early stopping
# [2024-05-06 13:37:01.223] The optimal number of layers: 2
# [2024-05-06 13:37:01.223] Start to evalute the model:
# [2024-05-06 13:37:01.224] Evaluating cascade layer = 0
# [2024-05-06 13:37:01.298] Evaluating cascade layer = 1
# Reynolds y_4 0.3039090895223879 0.3559309850464578 -7.3 24.9
# [2024-05-06 13:37:01.377] Start to fit the model:
# [2024-05-06 13:37:01.377] Fitting cascade layer = 0
# [2024-05-06 13:37:06.294] layer = 0  | Val MSE = 0.20033 | Elapsed = 4.917 s
# [2024-05-06 13:37:06.298] Fitting cascade layer = 1
# [2024-05-06 13:37:13.184] layer = 1  | Val MSE = 0.10450 | Elapsed = 6.886 s
# [2024-05-06 13:37:13.187] Fitting cascade layer = 2
# [2024-05-06 13:37:20.218] layer = 2  | Val MSE = 0.10357 | Elapsed = 7.031 s
# [2024-05-06 13:37:20.222] Fitting cascade layer = 3
# [2024-05-06 13:37:27.398] layer = 3  | Val MSE = 0.10601 | Elapsed = 7.176 s
# [2024-05-06 13:37:27.398] Early stopping counter: 1 out of 2
# [2024-05-06 13:37:27.402] Fitting cascade layer = 4
# [2024-05-06 13:37:34.520] layer = 4  | Val MSE = 0.10682 | Elapsed = 7.118 s
# [2024-05-06 13:37:34.520] Early stopping counter: 2 out of 2
# [2024-05-06 13:37:34.520] Handling early stopping
# [2024-05-06 13:37:34.520] The optimal number of layers: 3
# [2024-05-06 13:37:34.521] Start to evalute the model:
# [2024-05-06 13:37:34.521] Evaluating cascade layer = 0
# [2024-05-06 13:37:34.597] Evaluating cascade layer = 1
# [2024-05-06 13:37:34.674] Evaluating cascade layer = 2
# Reynolds y_6 0.12145510809621982 0.24558196038832156 -6.5 26.1
# [2024-05-06 13:37:34.755] Start to fit the model:
# [2024-05-06 13:37:34.755] Fitting cascade layer = 0
# [2024-05-06 13:37:39.719] layer = 0  | Val MSE = 0.36504 | Elapsed = 4.964 s
# [2024-05-06 13:37:39.723] Fitting cascade layer = 1
# [2024-05-06 13:37:46.994] layer = 1  | Val MSE = 0.28612 | Elapsed = 7.271 s
# [2024-05-06 13:37:46.997] Fitting cascade layer = 2
# [2024-05-06 13:37:54.390] layer = 2  | Val MSE = 0.28851 | Elapsed = 7.393 s
# [2024-05-06 13:37:54.390] Early stopping counter: 1 out of 2
# [2024-05-06 13:37:54.394] Fitting cascade layer = 3
# [2024-05-06 13:38:01.704] layer = 3  | Val MSE = 0.28857 | Elapsed = 7.310 s
# [2024-05-06 13:38:01.704] Early stopping counter: 2 out of 2
# [2024-05-06 13:38:01.704] Handling early stopping
# [2024-05-06 13:38:01.705] The optimal number of layers: 2
# [2024-05-06 13:38:01.705] Start to evalute the model:
# [2024-05-06 13:38:01.706] Evaluating cascade layer = 0
# [2024-05-06 13:38:01.781] Evaluating cascade layer = 1
# Reynolds y_5 0.3064366226624356 0.3909532100340135 -7.9 27.4
# [2024-05-06 13:38:01.863] Start to fit the model:
# [2024-05-06 13:38:01.863] Fitting cascade layer = 0
# [2024-05-06 13:38:05.124] layer = 0  | Val MSE = 5.17877 | Elapsed = 3.261 s
# [2024-05-06 13:38:05.128] Fitting cascade layer = 1
# [2024-05-06 13:38:10.387] layer = 1  | Val MSE = 4.81843 | Elapsed = 5.259 s
# [2024-05-06 13:38:10.390] Fitting cascade layer = 2
# [2024-05-06 13:38:15.631] layer = 2  | Val MSE = 4.87010 | Elapsed = 5.242 s
# [2024-05-06 13:38:15.631] Early stopping counter: 1 out of 2
# [2024-05-06 13:38:15.634] Fitting cascade layer = 3
# [2024-05-06 13:38:20.983] layer = 3  | Val MSE = 4.78692 | Elapsed = 5.348 s
# [2024-05-06 13:38:20.986] Fitting cascade layer = 4
# [2024-05-06 13:38:26.427] layer = 4  | Val MSE = 4.76733 | Elapsed = 5.441 s
# [2024-05-06 13:38:26.430] Fitting cascade layer = 5
# [2024-05-06 13:38:31.778] layer = 5  | Val MSE = 4.82526 | Elapsed = 5.348 s
# [2024-05-06 13:38:31.778] Early stopping counter: 1 out of 2
# [2024-05-06 13:38:31.781] Fitting cascade layer = 6
# [2024-05-06 13:38:37.125] layer = 6  | Val MSE = 4.77765 | Elapsed = 5.344 s
# [2024-05-06 13:38:37.125] Early stopping counter: 2 out of 2
# [2024-05-06 13:38:37.126] Handling early stopping
# [2024-05-06 13:38:37.126] The optimal number of layers: 5
# [2024-05-06 13:38:37.126] Start to evalute the model:
# [2024-05-06 13:38:37.127] Evaluating cascade layer = 0
# [2024-05-06 13:38:37.179] Evaluating cascade layer = 1
# [2024-05-06 13:38:37.232] Evaluating cascade layer = 2
# [2024-05-06 13:38:37.286] Evaluating cascade layer = 3
# [2024-05-06 13:38:37.339] Evaluating cascade layer = 4
# Reynolds y_1 5.126022455235601 1.3134637854064066 -5.5 40.3
# [2024-05-06 13:38:37.399] Start to fit the model:
# [2024-05-06 13:38:37.399] Fitting cascade layer = 0
# [2024-05-06 13:38:42.461] layer = 0  | Val MSE = 0.17227 | Elapsed = 5.063 s
# [2024-05-06 13:38:42.465] Fitting cascade layer = 1
# [2024-05-06 13:38:49.500] layer = 1  | Val MSE = 0.08046 | Elapsed = 7.035 s
# [2024-05-06 13:38:49.504] Fitting cascade layer = 2
# [2024-05-06 13:38:56.844] layer = 2  | Val MSE = 0.07450 | Elapsed = 7.340 s
# [2024-05-06 13:38:56.848] Fitting cascade layer = 3
# [2024-05-06 13:39:04.176] layer = 3  | Val MSE = 0.07575 | Elapsed = 7.328 s
# [2024-05-06 13:39:04.177] Early stopping counter: 1 out of 2
# [2024-05-06 13:39:04.180] Fitting cascade layer = 4
# [2024-05-06 13:39:11.418] layer = 4  | Val MSE = 0.07800 | Elapsed = 7.238 s
# [2024-05-06 13:39:11.419] Early stopping counter: 2 out of 2
# [2024-05-06 13:39:11.419] Handling early stopping
# [2024-05-06 13:39:11.419] The optimal number of layers: 3
# [2024-05-06 13:39:11.420] Start to evalute the model:
# [2024-05-06 13:39:11.420] Evaluating cascade layer = 0
# [2024-05-06 13:39:11.496] Evaluating cascade layer = 1
# [2024-05-06 13:39:11.572] Evaluating cascade layer = 2
# Reynolds y_7 0.06695514887921186 0.18533792339852606 -5.8 25.3
# [2024-05-06 13:39:11.654] Start to fit the model:
# [2024-05-06 13:39:11.654] Fitting cascade layer = 0
# [2024-05-06 13:39:14.622] layer = 0  | Val MSE = 0.13482 | Elapsed = 2.968 s
# [2024-05-06 13:39:14.625] Fitting cascade layer = 1
# [2024-05-06 13:39:18.726] layer = 1  | Val MSE = 0.02957 | Elapsed = 4.101 s
# [2024-05-06 13:39:18.729] Fitting cascade layer = 2
# [2024-05-06 13:39:22.705] layer = 2  | Val MSE = 0.02323 | Elapsed = 3.976 s
# [2024-05-06 13:39:22.707] Fitting cascade layer = 3
# [2024-05-06 13:39:26.719] layer = 3  | Val MSE = 0.02202 | Elapsed = 4.012 s
# [2024-05-06 13:39:26.721] Fitting cascade layer = 4
# [2024-05-06 13:39:30.711] layer = 4  | Val MSE = 0.02170 | Elapsed = 3.989 s
# [2024-05-06 13:39:30.714] Fitting cascade layer = 5
# [2024-05-06 13:39:34.736] layer = 5  | Val MSE = 0.02178 | Elapsed = 4.023 s
# [2024-05-06 13:39:34.736] Early stopping counter: 1 out of 2
# [2024-05-06 13:39:34.739] Fitting cascade layer = 6
# [2024-05-06 13:39:38.772] layer = 6  | Val MSE = 0.02161 | Elapsed = 4.033 s
# [2024-05-06 13:39:38.775] Fitting cascade layer = 7
# [2024-05-06 13:39:42.805] layer = 7  | Val MSE = 0.02165 | Elapsed = 4.030 s
# [2024-05-06 13:39:42.805] Early stopping counter: 1 out of 2
# [2024-05-06 13:39:42.807] Fitting cascade layer = 8
# [2024-05-06 13:39:46.877] layer = 8  | Val MSE = 0.02181 | Elapsed = 4.069 s
# [2024-05-06 13:39:46.877] Early stopping counter: 2 out of 2
# [2024-05-06 13:39:46.877] Handling early stopping
# [2024-05-06 13:39:46.877] The optimal number of layers: 7
# [2024-05-06 13:39:46.878] Start to evalute the model:
# [2024-05-06 13:39:46.878] Evaluating cascade layer = 0
# [2024-05-06 13:39:46.923] Evaluating cascade layer = 1
# [2024-05-06 13:39:46.966] Evaluating cascade layer = 2
# [2024-05-06 13:39:47.009] Evaluating cascade layer = 3
# [2024-05-06 13:39:47.051] Evaluating cascade layer = 4
# [2024-05-06 13:39:47.094] Evaluating cascade layer = 5
# [2024-05-06 13:39:47.136] Evaluating cascade layer = 6
# Reynolds y_8 0.026175499392032134 0.11147160471331376 1.3 24.2
# [2024-05-06 13:39:47.185] Start to fit the model:
# [2024-05-06 13:39:47.185] Fitting cascade layer = 0
# [2024-05-06 13:39:52.284] layer = 0  | Val MSE = 1.05475 | Elapsed = 5.099 s
# [2024-05-06 13:39:52.288] Fitting cascade layer = 1
# [2024-05-06 13:39:59.678] layer = 1  | Val MSE = 0.91211 | Elapsed = 7.389 s
# [2024-05-06 13:39:59.681] Fitting cascade layer = 2
# [2024-05-06 13:40:07.128] layer = 2  | Val MSE = 0.91755 | Elapsed = 7.446 s
# [2024-05-06 13:40:07.128] Early stopping counter: 1 out of 2
# [2024-05-06 13:40:07.132] Fitting cascade layer = 3
# [2024-05-06 13:40:14.465] layer = 3  | Val MSE = 0.91674 | Elapsed = 7.334 s
# [2024-05-06 13:40:14.465] Early stopping counter: 2 out of 2
# [2024-05-06 13:40:14.465] Handling early stopping
# [2024-05-06 13:40:14.466] The optimal number of layers: 2
# [2024-05-06 13:40:14.466] Start to evalute the model:
# [2024-05-06 13:40:14.467] Evaluating cascade layer = 0
# [2024-05-06 13:40:14.543] Evaluating cascade layer = 1
# Reynolds y_3 1.0938026638116862 0.7207714885507774 -8.6 31.5
# [2024-05-06 13:40:14.627] Start to fit the model:
# [2024-05-06 13:40:14.627] Fitting cascade layer = 0
# [2024-05-06 13:40:21.045] layer = 0  | Val MSE = 2.55739 | Elapsed = 6.418 s
# [2024-05-06 13:40:21.050] Fitting cascade layer = 1
# [2024-05-06 13:40:30.528] layer = 1  | Val MSE = 2.35945 | Elapsed = 9.479 s
# [2024-05-06 13:40:30.533] Fitting cascade layer = 2
# [2024-05-06 13:40:39.994] layer = 2  | Val MSE = 2.35374 | Elapsed = 9.461 s
# [2024-05-06 13:40:39.998] Fitting cascade layer = 3
# [2024-05-06 13:40:49.513] layer = 3  | Val MSE = 2.33210 | Elapsed = 9.515 s
# [2024-05-06 13:40:49.517] Fitting cascade layer = 4
# [2024-05-06 13:40:59.049] layer = 4  | Val MSE = 2.36456 | Elapsed = 9.532 s
# [2024-05-06 13:40:59.049] Early stopping counter: 1 out of 2
# [2024-05-06 13:40:59.053] Fitting cascade layer = 5
# [2024-05-06 13:41:08.507] layer = 5  | Val MSE = 2.36742 | Elapsed = 9.454 s
# [2024-05-06 13:41:08.507] Early stopping counter: 2 out of 2
# [2024-05-06 13:41:08.507] Handling early stopping
# [2024-05-06 13:41:08.507] The optimal number of layers: 4
# [2024-05-06 13:41:08.508] Start to evalute the model:
# [2024-05-06 13:41:08.508] Evaluating cascade layer = 0
# [2024-05-06 13:41:08.607] Evaluating cascade layer = 1
# [2024-05-06 13:41:08.708] Evaluating cascade layer = 2
# [2024-05-06 13:41:08.810] Evaluating cascade layer = 3
# Reynolds y_2 2.4384381634267562 1.0717058828437915 -9.7 41.0
# [2024-05-06 13:41:08.969] Start to fit the model:
# [2024-05-06 13:41:08.969] Fitting cascade layer = 0
# [2024-05-06 13:42:10.359] layer = 0  | Val MSE = 0.07792 | Elapsed = 61.391 s
# [2024-05-06 13:42:10.370] Fitting cascade layer = 1
# [2024-05-06 13:43:12.100] layer = 1  | Val MSE = 0.04212 | Elapsed = 61.730 s
# [2024-05-06 13:43:12.110] Fitting cascade layer = 2
# [2024-05-06 13:44:13.425] layer = 2  | Val MSE = 0.03944 | Elapsed = 61.314 s
# [2024-05-06 13:44:13.435] Fitting cascade layer = 3
# [2024-05-06 13:45:14.764] layer = 3  | Val MSE = 0.03956 | Elapsed = 61.329 s
# [2024-05-06 13:45:14.764] Early stopping counter: 1 out of 2
# [2024-05-06 13:45:14.774] Fitting cascade layer = 4
# [2024-05-06 13:46:16.665] layer = 4  | Val MSE = 0.04028 | Elapsed = 61.890 s
# [2024-05-06 13:46:16.665] Early stopping counter: 2 out of 2
# [2024-05-06 13:46:16.665] Handling early stopping
# [2024-05-06 13:46:16.665] The optimal number of layers: 3
# [2024-05-06 13:46:16.666] Start to evalute the model:
# [2024-05-06 13:46:16.674] Evaluating cascade layer = 0
# [2024-05-06 13:46:16.969] Evaluating cascade layer = 1
# [2024-05-06 13:46:17.272] Evaluating cascade layer = 2
# UK y_10 0.07794851869849138 0.15305928979793598 0.5 22.0
# [2024-05-06 13:46:17.619] Start to fit the model:
# [2024-05-06 13:46:17.619] Fitting cascade layer = 0
# [2024-05-06 13:47:19.056] layer = 0  | Val MSE = 0.08212 | Elapsed = 61.437 s
# [2024-05-06 13:47:19.067] Fitting cascade layer = 1
# [2024-05-06 13:48:21.567] layer = 1  | Val MSE = 0.05587 | Elapsed = 62.500 s
# [2024-05-06 13:48:21.577] Fitting cascade layer = 2
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f0389628950>>
# Traceback (most recent call last):
#   File "/home/keen/.pyenv/versions/3.11.8/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 790, in _clean_thread_parent_frames
#     active_threads = {thread.ident for thread in threading.enumerate()}
#                                                  ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/keen/.pyenv/versions/3.11.8/lib/python3.11/threading.py", line 1510, in enumerate
#     return list(_active.values()) + list(_limbo.values())
#                 ^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       8 model = CascadeForestRegressor(random_state=1)
#       9 dat = all_data[ds_name][depth]
# ---> 10 model.fit(dat["train"]["X"].reshape(-1,dat["train"]["X"].shape[2]), dat["train"]["y"].flatten())
#      11 y_pred = model.predict(dat["test"]["X"].reshape(-1,dat["test"]["X"].shape[2]))
#      12 mse_score = mean_squared_error(y_pred, dat["test"]["y"].flatten())
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/cascade.py:1651, in CascadeForestRegressor.fit(self, X, y, sample_weight)
#    1648 # Check the input for regression
#    1649 self._check_target_values(y)
# -> 1651 super().fit(X, y, sample_weight)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/cascade.py:905, in BaseCascadeForest.fit(self, X, y, sample_weight)
#     902     print(msg.format(_utils.ctime(), layer_idx))
#     904 tic = time.time()
# --> 905 X_aug_train_ = layer_.fit_transform(
#     906     X_middle_train_, y, sample_weight=sample_weight
#     907 )
#     908 toc = time.time()
#     909 training_time = toc - tic
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/_layer.py:304, in RegressionCascadeLayer.fit_transform(self, X, y, sample_weight)
#     302 # A random forest and an extremely random forest will be fitted
#     303 for estimator_idx in range(self.n_estimators // 2):
# --> 304     X_aug_, _estimator = _build_estimator(
#     305         X,
#     306         y,
#     307         self.layer_idx,
#     308         estimator_idx,
#     309         "rf",
#     310         self._make_estimator(estimator_idx, "rf"),
#     311         oob_decision_function,
#     312         self.partial_mode,
#     313         self.buffer,
#     314         self.verbose,
#     315         sample_weight,
#     316     )
#     317     X_aug.append(X_aug_)
#     318     key = "{}-{}-{}".format(self.layer_idx, estimator_idx, "rf")
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/_layer.py:40, in _build_estimator(X, y, layer_idx, estimator_idx, estimator_name, estimator, oob_decision_function, partial_mode, buffer, verbose, sample_weight)
#      37     key = estimator_name + "_" + str(estimator_idx)
#      38     print(msg.format(_utils.ctime(), key, layer_idx))
# ---> 40 X_aug_train = estimator.fit_transform(X, y, sample_weight)
#      41 oob_decision_function += estimator.oob_decision_function_
#      43 if partial_mode:
#      44     # Cache the fitted estimator in out-of-core mode
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/_estimator.py:212, in Estimator.fit_transform(self, X, y, sample_weight)
#     211 def fit_transform(self, X, y, sample_weight=None):
# --> 212     self.estimator_.fit(X, y, sample_weight)
#     213     return self.oob_decision_function_
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/forest.py:462, in BaseForest.fit(self, X, y, sample_weight)
#     459 mask = np.zeros(n_samples)
#     461 lock = threading.Lock()
# --> 462 rets = Parallel(
#     463     n_jobs=n_jobs,
#     464     verbose=self.verbose,
#     465     prefer="threads",
#     466     require="sharedmem",
#     467 )(
#     468     delayed(_parallel_build_trees)(
#     469         t,
#     470         X,
#     471         y,
#     472         n_samples_bootstrap,
#     473         sample_weight,
#     474         oob_decision_function,
#     475         mask,
#     476         is_classifier(self),
#     477         lock,
#     478     )
#     479     for i, t in enumerate(trees)
#     480 )
#     481 # Collect newly grown trees
#     482 for feature, threshold, children, value in rets:
#     483
#     484     # No check on feature and threshold since 1-D array is always
#     485     # C-aligned and F-aligned.
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/forest.py:124, in _parallel_build_trees(tree, X, y, n_samples_bootstrap, sample_weight, out, mask, is_classifier, lock)
#     122 if sample_weight is not None:
#     123     sample_weight = sample_weight[sample_mask]
# --> 124 feature, threshold, children, value = tree.fit(
#     125     X[sample_mask],
#     126     y[sample_mask],
#     127     sample_weight=sample_weight,
#     128     check_input=False,
#     129 )
#     131 if not children.flags["C_CONTIGUOUS"]:
#     132     children = np.ascontiguousarray(children)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/tree/tree.py:536, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     532 def fit(
#     533     self, X, y, sample_weight=None, check_input=True, X_idx_sorted=None
#     534 ):
# --> 536     return super().fit(
#     537         X,
#     538         y,
#     539         sample_weight=sample_weight,
#     540         check_input=check_input,
#     541         X_idx_sorted=X_idx_sorted,
#     542     )
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/deepforest/tree/tree.py:376, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     359     self.tree_ = Tree(
#     360         self.n_features_,
#     361         # TODO: tree should't need this in this case
#     362         np.array([1] * self.n_outputs_, dtype=np.int32),
#     363         self.n_outputs_,
#     364     )
#     366 builder = DepthFirstTreeBuilder(
#     367     splitter,
#     368     min_samples_split,
#    (...)
#     373     min_impurity_split,
#     374 )
# --> 376 builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     378 if self.n_outputs_ == 1 and is_classifier(self):
#     379     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# # Boosted Forest

# %%
from boosted_forest import CascadeBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

for ds_name in all_data:
    for depth in all_data[ds_name]:
        model = CascadeBoostingRegressor(C=1000, n_layers=10, verbose=2, n_estimators = 4, max_depth=2, n_iter_no_change = 1, validation_fraction = 0.1)
        dat = all_data[ds_name][depth]
        model.fit(dat["train"]["X"].reshape(-1,dat["train"]["X"].shape[2]), dat["train"]["y"].flatten())
        y_pred = model.predict(dat["test"]["X"].reshape(-1,dat["test"]["X"].shape[2]))
        mse_score = mean_squared_error(y_pred, dat["test"]["y"].flatten())
        mae_score = mean_absolute_error(y_pred, dat["test"]["y"].flatten())
        print(ds_name,depth,mse_score, mae_score, dat["test"]["y"].min(),dat["test"]["y"].max())
        del model
        break
    break
# Out:
# Init:  [[10.51245275]
#  [10.51245275]
#  [10.51245275]
#  [10.51245275]
#  [10.51245275]]
# 1715082681.1766236 Binning training data: 0.054 MB => 0.014 MB | Elapsed = 0.003 s
#       Iter       Train Loss   Remaining Time
# 1715082681.1769106 Binning training data: 0.036 MB => 0.005 MB | Elapsed = 0.000 s
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
#          1           0.8299           10.36m
# Regressor loss:  0.8298998892088578
# 1715082888.4151466 Binning testing data: 0.006 MB => 0.002 MB | Elapsed = 0.000 s
# 1715082888.4152415 Binning testing data: 0.002 MB => 0.002 MB | Elapsed = 0.000 s
# 1715082888.4154701 Binning testing data: 0.004 MB => 0.001 MB | Elapsed = 0.000 s
# val loss:  0.9020747629268409
# 1715082888.4310873 Binning training data: 0.036 MB => 0.005 MB | Elapsed = 0.001 s
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
#          2           0.3481            6.86m
# Regressor loss:  0.3480747797681043
# 1715083092.5349212 Binning testing data: 0.004 MB => 0.001 MB | Elapsed = 0.000 s
# val loss:  0.37463015531696914
# 1715083092.5484247 Binning training data: 0.036 MB => 0.005 MB | Elapsed = 0.001 s
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
#          3           0.2690            3.31m
# Regressor loss:  0.2689880336570357
# 1715083277.0525615 Binning testing data: 0.004 MB => 0.001 MB | Elapsed = 0.000 s
# val loss:  0.2923502674794797
# 1715083277.0674548 Binning training data: 0.036 MB => 0.005 MB | Elapsed = 0.001 s
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
#          4           0.2129            0.00s
# Regressor loss:  0.2129348839347595
# 1715083480.1577885 Binning testing data: 0.004 MB => 0.001 MB | Elapsed = 0.000 s
# val loss:  0.2440272292030031
# 1715083480.1721725 Binning training data: 0.036 MB => 0.005 MB | Elapsed = 0.001 s
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
# Fit forest
# Fit reg
#          5           0.1893         -187.67s
# Regressor loss:  0.18925046854294258
# 1715083619.5469801 Binning testing data: 0.004 MB => 0.001 MB | Elapsed = 0.000 s
# val loss:  0.21795813304737344
# 1715083619.5664432 Binning training data: 0.036 MB => 0.005 MB | Elapsed = 0.001 s
# Fit forest
# Fit reg

# %%
x_train.shape[1:]

# %%
batch_size

# %%
x_train.shape

# %%
for ds in all_data:
    for k in all_data[ds]:
        print(all_data[ds][k]['train']['X'].shape,all_data[ds][k]['test']['X'].shape)

# %%
195 / 9

# %%
# !pip install optuna

# %%
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

for ds_name in all_data:
    for depth in all_data[ds_name]:
        for n_estimators in [10, 30, 100]:
            for tdepth in [2,3,5,7,10,12]:
                model = RandomForestRegressor(n_estimators = n_estimators, max_depth = tdepth)
                dat = all_data[ds_name][depth]
                model.fit(dat["train"]["X"].reshape(-1,dat["train"]["X"].shape[2]), dat["train"]["y"].flatten())
                y_pred = model.predict(dat["test"]["X"].reshape(-1,dat["test"]["X"].shape[2]))
                mse_score = mean_squared_error(y_pred, dat["test"]["y"].flatten())
                mae_score = mean_absolute_error(y_pred, dat["test"]["y"].flatten())
                
                print(n_estimators, tdepth, ds_name,depth,mse_score, mae_score, dat["test"]["y"].min(),dat["test"]["y"].max())
                del model
        break
    break
# Out:
# 10 2 Reynolds y_7 2.861483474496024 1.3550672484022575 -4.6 25.6
# 10 3 Reynolds y_7 0.9156763332221917 0.7885185664113755 -4.6 25.6
# 10 5 Reynolds y_7 0.143573315042482 0.2553926016179321 -4.6 25.6
# 10 7 Reynolds y_7 0.08824445350088257 0.18953626082231115 -4.6 25.6
# 10 10 Reynolds y_7 0.07920205223009348 0.17827083270956548 -4.6 25.6
# 10 12 Reynolds y_7 0.08024693505945753 0.1795602261954935 -4.6 25.6
# 30 2 Reynolds y_7 2.980888618552507 1.3921425182411784 -4.6 25.6
# 30 3 Reynolds y_7 0.7790287329788175 0.716325318729382 -4.6 25.6
# 30 5 Reynolds y_7 0.1456837722385795 0.261078756462858 -4.6 25.6
# 30 7 Reynolds y_7 0.08450521865816879 0.18189454865156562 -4.6 25.6
# 30 10 Reynolds y_7 0.07705791724384023 0.1736416581574221 -4.6 25.6
# 30 12 Reynolds y_7 0.07829331089154791 0.1759557687361989 -4.6 25.6
# 100 2 Reynolds y_7 2.905335125050246 1.378977565656915 -4.6 25.6
# 100 3 Reynolds y_7 0.8194488277381309 0.7426748586574657 -4.6 25.6
# 100 5 Reynolds y_7 0.14290678702663934 0.2543433932590772 -4.6 25.6
# 100 7 Reynolds y_7 0.0835836351529254 0.179943060148493 -4.6 25.6
# 100 10 Reynolds y_7 0.07653586708844637 0.17275314323562796 -4.6 25.6
# 100 12 Reynolds y_7 0.07765911394216049 0.17539589837714323 -4.6 25.6
